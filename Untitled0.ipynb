# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj74/Linux74/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello ,Guys!")
# Out:
# Hello ,Guys!

# %%
wallet_amount = 100
ticket_price = 120
if wallet_amount > ticket_priceprint ("Go for a movies")
      else
